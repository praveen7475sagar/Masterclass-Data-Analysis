# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_excel('C:\\Users\\ARUN PRAVEEN\\Desktop\\masterclass1.xlsx')
df2=pd.read_excel('C:\\Users\\ARUN PRAVEEN\\Desktop\\masterclass2.xlsx')
df3=pd.read_excel('C:\\Users\\ARUN PRAVEEN\\Desktop\\masterclass3.xlsx')
df4=pd.read_excel('C:\\Users\\ARUN PRAVEEN\\Desktop\\masterclass4.xlsx')
df5=pd.read_excel('C:\\Users\\ARUN PRAVEEN\\Desktop\\masterclass5.xlsx')
df6=pd.read_excel('C:\\Users\\ARUN PRAVEEN\\Desktop\\masterclass6.xlsx')
df7=pd.read_excel('C:\\Users\\ARUN PRAVEEN\\Desktop\\masterclass7.xlsx')

# %%
#Analysing and cleaning the 1st dataset
df1.head()
# Out:
#                 Timestamp    First Name  Last Name       City  Unnamed: 4
# 0 2020-09-28 00:10:58.066      Pranshu   Bhatnagar  Moradabad         1.0
# 1 2020-09-28 07:17:13.080        Kumari     Garima      Delhi        35.0
# 2 2020-09-28 09:12:18.512  Damarakeswar   Guddanti      ELURU         1.0
# 3 2020-09-28 09:41:07.900        Manish     Bharti  Bangalore        17.0
# 4 2020-09-28 10:59:00.443        Rakesh   Tripathi       Pune        52.0

# %%
df1.drop(['First Name','Last Name','Unnamed: 4'],axis=1,inplace=True)

# %%
df1['masterclass topic']='Basics of Excel'

# %%
df1['Timestamp']=pd.DatetimeIndex(df1['Timestamp']).month

# %%
df1['Timestamp'].value_counts()
# Out:
# 10    646
# 9      11
# Name: Timestamp, dtype: int64

# %%
#Analysing and cleaning the 2nd dataset
df2.head()
# Out:
#                 Timestamp First Name  Last Name        City Unnamed: 4  \
# 0 2020-08-09 21:10:59.330      Anuja    Kharkar      Bhopal      canva
# 1 2020-08-09 21:27:42.550  Abhishek   Bhardwaj    New delhi      canva
# 2 2020-08-09 21:29:55.608    Manjiri     Sonone        Pune      canva
# 3 2020-08-09 21:30:34.752    Anthima      Singh  Hyderabad       canva
# 4 2020-08-09 21:36:48.633    Dharini       Shah      Mumbai      canva
#
#                 Unnamed: 5
# 0        canvaAnujaKharkar
# 1  canvaAbhishek Bhardwaj
# 2       canvaManjiriSonone
# 3        canvaAnthimaSingh
# 4         canvaDhariniShah

# %%
df2.drop(['First Name','Last Name','Unnamed: 4','Unnamed: 5'],axis=1,inplace=True)

# %%
df2['Timestamp']=pd.DatetimeIndex(df2['Timestamp']).month

# %%
df2['masterclass topic']='Basics of canva(graphic design)'

# %%
df2.head()
# Out:
#    Timestamp        City                masterclass topic
# 0          8      Bhopal  Basics of canva(graphic design)
# 1          8   New delhi  Basics of canva(graphic design)
# 2          8        Pune  Basics of canva(graphic design)
# 3          8  Hyderabad   Basics of canva(graphic design)
# 4          8      Mumbai  Basics of canva(graphic design)

# %%
#Analysing and cleaning the third dataset
df3.head()
# Out:
#                 Timestamp First Name  Last Name            City Unnamed: 4  \
# 0 2020-08-02 15:05:28.216      saket   deshmukh            Pune     Public
# 1 2020-08-02 22:13:36.424    Mishika     Sharma         Gurgaon     Public
# 2 2020-08-02 22:16:43.616     Diksha        Deb  Silchar, Assam     Public
# 3 2020-08-02 22:17:19.184     Lohith  Bollineni         Chennai     Public
# 4 2020-08-02 22:20:47.635     Rutuja   Ghorpade            Pune     Public
#
#               Unnamed: 5
# 0    Publicsaketdeshmukh
# 1    PublicMishikaSharma
# 2        PublicDikshaDeb
# 3  PublicLohithBollineni
# 4   PublicRutujaGhorpade

# %%
df3.drop(['First Name','Last Name','Unnamed: 4','Unnamed: 5'],axis=1,inplace=True)

# %%
df3['Timestamp']=pd.DatetimeIndex(df3['Timestamp']).month

# %%
df3['masterclass topic']='Public speaking'

# %%
df3.head()
# Out:
#    Timestamp            City masterclass topic
# 0          8            Pune   Public speaking
# 1          8         Gurgaon   Public speaking
# 2          8  Silchar, Assam   Public speaking
# 3          8         Chennai   Public speaking
# 4          8            Pune   Public speaking

# %%
#cleaning the 4th dataset
df4.head()
# Out:
#                 Timestamp First Name Last Name        City Unnamed: 4  \
# 0 2020-08-14 07:58:54.049      JYOTI   GOSWAMI  Bikramganj    podcast
# 1 2020-08-14 09:31:51.186       Anil     Kumar       Arwal    podcast
# 2 2020-08-14 12:59:11.465   Sandhya     Shakya    Banglore    podcast
# 3 2020-08-14 15:23:18.877    Rajnish     Tomar       Delhi    podcast
# 4 2020-08-14 16:21:04.926    Sheril   Gaikwad      Mumbai     podcast
#
#                Unnamed: 5
# 0     podcastJYOTIGOSWAMI
# 1        podcastAnilKumar
# 2   podcastSandhya Shakya
# 3     podcastRajnishTomar
# 4  podcastSheril Gaikwad

# %%
df4.drop(['First Name','Last Name','Unnamed: 4','Unnamed: 5'],axis=1,inplace=True)

# %%
df4['Timestamp']=pd.DatetimeIndex(df4['Timestamp']).month

# %%
df4['masterclass topic']='The podcast'

# %%
#cleaning the 5 th dataset
df5.head()
# Out:
#                 Timestamp         First Name      City Last Name Unnamed: 4
# 0 2020-07-28 16:46:31.177            Samrita    Raipur       NaN        NaN
# 1 2020-07-28 16:46:43.534     Khushi Tiwari   Gurgaon        NaN        NaN
# 2 2020-07-28 16:48:02.362      Shreya Biswas    Bhilai       NaN        NaN
# 3 2020-07-28 16:49:58.147       Hardik Patni      Pune       NaN        NaN
# 4 2020-07-28 16:50:17.182  Anhad Preet Singh   Chennai       NaN        NaN

# %%
df5.drop(['First Name','Unnamed: 4','Last Name'],axis=1,inplace=True)

# %%
df5['Timestamp']=pd.DatetimeIndex(df5['Timestamp']).month

# %%
df5['masterclass topic']='Basics video Editing'

# %%
#cleaning the sixth dataset
df6.head()
# Out:
#                 Timestamp    First Name Last Name        City Unnamed: 4  \
# 0 2020-08-29 11:31:02.261           Raj      Maru      Mumbai   whatsapp
# 1 2020-08-29 16:33:59.010       Prachi   Agarwal   Moradabad    whatsapp
# 2 2020-08-29 18:08:10.918  Paramananda       Deka    Guwahati   whatsapp
# 3 2020-08-29 19:36:26.061        Rajesh     Kumar   Raebareli   whatsapp
# 4 2020-08-29 19:40:57.353     Akanksha     Kunwar    Dehradun   whatsapp
#
#                  Unnamed: 5
# 0           whatsappRajMaru
# 1   whatsappPrachi Agarwal
# 2  whatsappParamananda Deka
# 3       whatsappRajeshKumar
# 4   whatsappAkanksha Kunwar

# %%
df6.drop(['First Name','Last Name','Unnamed: 4','Unnamed: 5'],axis=1,inplace=True)

# %%
df6['Timestamp']=pd.DatetimeIndex(df6['Timestamp']).month

# %%
df6['masterclass topic']='Whatsapp marketing'

# %%
#cleaning the 7th dataset
df7.head()
# Out:
#                 Timestamp      First Name Last Name            City  \
# 0 2020-09-19 16:30:06.460         Deepali   Vandana          Mumbai
# 1 2020-09-19 17:18:17.638        Supriya     Glory       Bangalore
# 2 2020-09-19 19:29:09.356        Samiksha   Todaria        Dehradun
# 3 2020-09-20 03:33:16.894            Ajay  Kushwaha          Maihar
# 4 2020-09-20 16:50:17.189  Divya Sai Teja   Sindiri  Visakhapatnam
#
#   Unnamed: 4                Unnamed: 5
# 0        DMC         DMCDeepaliVandana
# 1        DMC         DMCSupriya Glory
# 2        DMC        DMCSamikshaTodaria
# 3        DMC           DMCAjayKushwaha
# 4        DMC  DMCDivya Sai TejaSindiri

# %%
df7.drop(['First Name','Last Name','Unnamed: 4','Unnamed: 5'],axis=1,inplace=True)

# %%
df7['Timestamp']=pd.DatetimeIndex(df7['Timestamp']).month

# %%
df7['masterclass topic']='Basics of Digital marketing'

# %%
Final=pd.concat([df1,df2,df3,df4,df5,df6,df7])

# %%
Final['City'].unique()
# Out:
# array(['Moradabad', 'Delhi', 'ELURU', 'Bangalore', 'Pune', 'SONEBHADRA',
#        'Bhubaneswar', 'Mumbai', 'New Delhi', 'MUMBAI', 'SILCHAR',
#        'Gurugram', 'Faridabad ', 'Bangalore South', 'Silchar', 'Bilaspur',
#        'Goregaon w, Mumbai', 'Near Dikshant international school',
#        'Tinsukia', 'Delhi ', 'Noida', 'Hyderabad', 'RANCHI', 'Tumkur',
#        'UDAIPUR', 'Gadarpur', 'Guwahati', 'Shahada', 'Kasaragod', 'Durg',
#        'Mohali', 'Kolkata', 'pune', 'Kanpur', 'Hisar', 'Ranchi', 'NASHIK',
#        'Guwahati ', 'Ahmedabad', 'Lucknow', 'Ghaziabad', 'Patna',
#        'Faridabad', 'Meerut', 'Accra', 'Tema', 'Jalgaon ', 'Malappuram',
#        'Hisar, Haryana', 'Gangtok', 'Coochbihar', 'Bidar', 'Amritsar',
#        'Malout,Punjab', 'Greater Noida (West)', 'Vadodara', 'Saharanpur',
#        'Kuruksethra ', 'New Delhi ', 'Selangor', 'Bengaluru', 'Indore',
#        'Dharamshala, Himachal Pradesh.', 'Trivandrum', 'Wai',
# ...

# %%
Final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2960 entries, 0 to 243
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Timestamp          2960 non-null   int64
#  1   City               2960 non-null   object
#  2   masterclass topic  2960 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 69.4+ KB

# %%
Final=Final.rename(columns={'Timestamp':'Month'},index={'ONE':'one'})

# %%
Finalexcel=Final.to_excel('C:\\Users\\ARUN PRAVEEN\\Desktop\\masterclass final.xlsx')
